# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
plt.style.use('dark_background')

df = pd.read_csv('basic_4FGL_DR4.csv') #converting the fermi dataset into a dataframe
df.iloc[0]
# Out:
# FL16Y          FL16Y J0000.0+314
# glon                     110.333
# glat                     -29.848
# association               blazar
# logS                     -11.682
# Name: 0, dtype: object
