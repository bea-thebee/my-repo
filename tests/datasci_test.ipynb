# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

val_df = pd.read_csv('valung.csv')
val_df.replace({'standard' : 0, 'test' : 1}, inplace=True)
val_df.replace({'Squamous' : 0, 'Small' : 1, 'Adeno' : 2, 'Large' : 3}, inplace=True)
val_df.corr(numeric_only=True).abs()
# Out:
# /tmp/ipykernel_4067/711187023.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   val_df.replace({'standard' : 0, 'test' : 1}, inplace=True)
# /tmp/ipykernel_4067/711187023.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   val_df.replace({'Squamous' : 0, 'Small' : 1, 'Adeno' : 2, 'Large' : 3}, inplace=True)
#            therapy      cell         t       kps  diagtime       age
# therapy   1.000000  0.011437  0.041531  0.031964  0.011580  0.076661
# cell      0.011437  1.000000  0.083079  0.087704  0.128426  0.092978
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

comet_df = pd.read_csv('Near-Earth_Comets_-_Orbital_Elements_rows.csv')
comet_df_no_na = comet_df.dropna(axis = 1, how='any')

comet_df_no_na['ref'].mode
# Out:
# <bound method Series.mode of 0            20
# 1            13
# 2       J863/77
# 3            74
# 4      IAUCAT03
#          ...
# 155          10
# 156           1
# 157           3
# 158           6
# 159           2
# Name: ref, Length: 160, dtype: object>
