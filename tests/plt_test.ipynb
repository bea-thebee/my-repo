# %%
import numpy as np
import matplotlib.pyplot as plt
xpts = np.array([1, 8])
ypts = np.array([7, 2])
plt.plot(xpts, ypts, 'dm-.');

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.array([40, 35, 10, 10, 5])
x = ['Italian', 'Thai', 'Hawaiian', 'Chinese', 'Other']
plt.style.use('default')
plt.title('Takeouts Ordered')
plt.bar(x, y);

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(10)
y= np.array([7,9,5,6,7,4,8,3,2,9])
plt.title('Random Data')
plt.scatter(x,y)
